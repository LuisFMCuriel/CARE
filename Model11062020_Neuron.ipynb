# %%
#Install and import dependencies
#Here, we install libraries which are not already included in Colab.
#!pip install tifffile # contains tools to operate tiff-files
#!pip install csbdeep  # contains tools for restoration of fluorescence microcopy images (Content-aware Image Restoration, CARE). It uses Keras and Tensorflow.
#!pip install memory_profiler
# !pip install memory_profiler
# %load_ext memory_profiler
# %tensorflow_version 1.x

import tensorflow as tf
if tf.test.gpu_device_name()=='':
  print('You do not have GPU access.') 
  print('Did you change your runtime ?') 
  print('If the runtime settings are correct then Google did not allocate GPU to your session')
  print('Expect slow performance. To access GPU try reconnecting later')

else:
  print('You have GPU access')

from tensorflow.python.client import device_lib 
device_lib.list_local_devices()

#@markdown ##Play the cell to train your neural network
#@markdown ###Remember to give your credentials, don't worry I will wait
#@markdown ## ¯ \ _ (ツ) _ / ¯
from __future__ import print_function, unicode_literals, absolute_import, division
from google.colab import drive
drive.mount('/content/gdrive') 
#Select the path to the script
Path_Train_script = "/content/gdrive/My Drive/Colab Notebooks" #@param {type:"string"}
import sys 
import os
sys.path.append(os.path.abspath(Path_Train_script))
import Training

#@markdown ###Path to training images:

# low SNR images
# low = "/content/gdrive/My Drive/Work/manuscript/Ongoing Projects/Zero-Cost Deep-Learning to Enhance Microscopy/Notebooks to be tested/Training datasets/CARE (2D)/Training - Low SNR images" #@param {type:"string"}
Training_source = "/content/gdrive/My Drive/CARE_2D_Neuron_10062020/Low/Random_selection" #@param {type:"string"}

# Ground truth images
# GT = "/content/gdrive/My Drive/Work/manuscript/Ongoing Projects/Zero-Cost Deep-Learning to Enhance Microscopy/Notebooks to be tested/Training datasets/CARE (2D)/Training - High SNR images" #@param {type:"string"}
Training_target = "/content/gdrive/My Drive/CARE_2D_Neuron_10062020/Max/Random_selection" #@param {type:"string"}

# model name and path
#@markdown ###Name of the model and path to model folder:
model_name = "Model11062020_Neuron" #@param {type:"string"}
model_path = "/content/gdrive/My Drive/cloud_colab/CARE_WORMS1/models" #@param {type:"string"}

#@markdown ####Use one image of the training set for visual assessment of the training:
Visual_validation_after_training = True #@param {type:"boolean"}
raw_data = False #@param {type:"boolean"}


# other parameters for training.
#@markdown ###Training Parameters
#@markdown Number of epochs:

number_of_epochs =  100#@param {type:"number"}

#@markdown Patch size (pixels) and number
patch_size =  64#@param {type:"number"} # in pixels

number_of_patches =   10#@param {type:"number"}


#@markdown ###Advanced Parameters

Use_Default_Advanced_Parameters = True #@param {type:"boolean"}
#@markdown ###If not, please input:

number_of_steps =  300 #@param {type:"number"}
batch_size =  64#@param {type:"number"}
percentage_validation =  15 #@param {type:"number"}


Training.train(Training_source, Training_target,
                model_name,
                model_path,
                Visual_validation_after_training,
                number_of_epochs,
                patch_size,
                number_of_patches,
                Use_Default_Advanced_Parameters,
                number_of_steps,
                batch_size,
                percentage_validation)
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.6/dist-packages (0.57.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from memory_profiler) (5.4.8)
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler
# You have GPU access
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Default advanced parameters enabled
# Loaded Input images (number, width, length) = (3000, 488, 1024)
# Loaded Output images (number, width, length) = (3000, 488, 1024)
# Parameters initiated.
# ==================================================================
#  3000 raw images x    1 transformations   =  3000 images
#  3000 images     x   10 patches per image = 30000 patches in total
# ==================================================================
# Input data:
# /content/: target='/content/gdrive/My Drive/CARE_2D_Neuron_10062020/Max/Random_selection', sources=['/content/gdrive/My Drive/CARE_2D_Neuron_10062020/Low/Random_selection'], axes='CYX', pattern='*.tif*'
# ==================================================================
# Transformations:
# 1 x Identity
# ==================================================================
# Patch size:
# 64 x 64
# ==================================================================
# 100%|██████████| 3000/3000 [02:46<00:00, 18.03it/s]
# Creating 2D training dataset
# number of training images:	 27000
# number of validation images:	 3000
# image size (2D):		 (64, 64)
# axes:				 SYXC
# channels in / out:		 1 / 1
# 422
# Config(axes='YXC', n_channel_in=1, n_channel_out=1, n_dim=2, probabilistic=False, train_batch_size=64, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0}, train_steps_per_epoch=422, train_tensorboard=True, unet_input_shape=(None, None, 1), unet_kern_size=5, unet_last_activation='linear', unet_n_depth=3, unet_n_first=32, unet_residual=True)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/csbdeep/utils/tf.py:239: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/csbdeep/utils/tf.py:267: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/csbdeep/utils/tf.py:274: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 422/422 [==============================] - 107s 253ms/step - loss: 0.0416 - mse: 0.0219 - mae: 0.0416 - val_loss: 0.0341 - val_mse: 0.0273 - val_mae: 0.0341
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/csbdeep/utils/tf.py:302: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0274 - mse: 0.0194 - mae: 0.0274 - val_loss: 0.0262 - val_mse: 0.0242 - val_mae: 0.0262
# Epoch 3/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0240 - mse: 0.0135 - mae: 0.0240 - val_loss: 0.0244 - val_mse: 0.0124 - val_mae: 0.0244
# Epoch 4/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0215 - mse: 0.0088 - mae: 0.0215 - val_loss: 0.0248 - val_mse: 0.0121 - val_mae: 0.0248
# Epoch 5/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0212 - mse: 0.0085 - mae: 0.0212 - val_loss: 0.0223 - val_mse: 0.0136 - val_mae: 0.0223
# Epoch 6/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0209 - mse: 0.0079 - mae: 0.0209 - val_loss: 0.0211 - val_mse: 0.0110 - val_mae: 0.0211
# Epoch 7/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0205 - mse: 0.0076 - mae: 0.0205 - val_loss: 0.0234 - val_mse: 0.0102 - val_mae: 0.0234
# Epoch 8/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0205 - mse: 0.0071 - mae: 0.0205 - val_loss: 0.0211 - val_mse: 0.0098 - val_mae: 0.0211
# Epoch 9/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0202 - mse: 0.0071 - mae: 0.0202 - val_loss: 0.0246 - val_mse: 0.0091 - val_mae: 0.0246
# Epoch 10/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0204 - mse: 0.0070 - mae: 0.0204 - val_loss: 0.0212 - val_mse: 0.0096 - val_mae: 0.0212
# Epoch 11/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0203 - mse: 0.0070 - mae: 0.0203 - val_loss: 0.0209 - val_mse: 0.0106 - val_mae: 0.0209
# Epoch 12/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0201 - mse: 0.0069 - mae: 0.0201 - val_loss: 0.0205 - val_mse: 0.0101 - val_mae: 0.0205
# Epoch 13/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0202 - mse: 0.0067 - mae: 0.0202 - val_loss: 0.0209 - val_mse: 0.0108 - val_mae: 0.0209
# Epoch 14/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0201 - mse: 0.0068 - mae: 0.0201 - val_loss: 0.0204 - val_mse: 0.0092 - val_mae: 0.0204
# Epoch 15/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0199 - mse: 0.0066 - mae: 0.0199 - val_loss: 0.0203 - val_mse: 0.0092 - val_mae: 0.0203
# Epoch 16/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0200 - mse: 0.0065 - mae: 0.0200 - val_loss: 0.0206 - val_mse: 0.0099 - val_mae: 0.0206
# Epoch 17/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.
100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0160 - mse: 0.0020 - mae: 0.0160 - val_loss: 0.0187 - val_mse: 0.0064 - val_mae: 0.0187
# Epoch 62/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0158 - mse: 0.0018 - mae: 0.0158 - val_loss: 0.0190 - val_mse: 0.0063 - val_mae: 0.0190
# Epoch 63/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0158 - mse: 0.0017 - mae: 0.0158 - val_loss: 0.0189 - val_mse: 0.0060 - val_mae: 0.0189
# Epoch 64/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0156 - mse: 0.0017 - mae: 0.0156 - val_loss: 0.0192 - val_mse: 0.0061 - val_mae: 0.0192
# Epoch 65/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0155 - mse: 0.0016 - mae: 0.0155 - val_loss: 0.0193 - val_mse: 0.0064 - val_mae: 0.0193
# Epoch 66/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0156 - mse: 0.0016 - mae: 0.0156 - val_loss: 0.0185 - val_mse: 0.0060 - val_mae: 0.0185
# Epoch 67/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0154 - mse: 0.0016 - mae: 0.0154 - val_loss: 0.0193 - val_mse: 0.0064 - val_mae: 0.0193
# Epoch 68/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0155 - mse: 0.0016 - mae: 0.0155 - val_loss: 0.0190 - val_mse: 0.0059 - val_mae: 0.0190
# Epoch 69/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0153 - mse: 0.0015 - mae: 0.0153 - val_loss: 0.0184 - val_mse: 0.0061 - val_mae: 0.0184
# Epoch 70/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0153 - mse: 0.0015 - mae: 0.0153 - val_loss: 0.0186 - val_mse: 0.0061 - val_mae: 0.0186
# Epoch 71/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0152 - mse: 0.0014 - mae: 0.0152 - val_loss: 0.0185 - val_mse: 0.0057 - val_mae: 0.0185
# Epoch 72/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0152 - mse: 0.0014 - mae: 0.0152 - val_loss: 0.0188 - val_mse: 0.0063 - val_mae: 0.0188
# Epoch 73/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0152 - mse: 0.0014 - mae: 0.0152 - val_loss: 0.0189 - val_mse: 0.0057 - val_mae: 0.0189
# Epoch 74/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0150 - mse: 0.0014 - mae: 0.0150 - val_loss: 0.0184 - val_mse: 0.0064 - val_mae: 0.0184
# Epoch 75/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0149 - mse: 0.0014 - mae: 0.0149 - val_loss: 0.0188 - val_mse: 0.0064 - val_mae: 0.0188
# Epoch 76/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0148 - mse: 0.0014 - mae: 0.0148 - val_loss: 0.0185 - val_mse: 0.0063 - val_mae: 0.0185
# Epoch 77/100
# 422/422 [==============================] - 94s 224ms/step - loss: 0.0148 - mse: 0.0014 - mae: 0.0148 - val_loss: 0.0186 - val_mse: 0.0063 - val_mae: 0.0186
# Epoch 78/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0145 - mse: 0.0013 - mae: 0.0145 - val_loss: 0.0185 - val_mse: 0.0056 - val_mae: 0.0185
# Epoch 79/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0145 - mse: 0.0013 - mae: 0.0145 - val_loss: 0.0199 - val_mse: 0.0062 - val_mae: 0.0199
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 80/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0136 - mse: 0.0011 - mae: 0.0136 - val_loss: 0.0193 - val_mse: 0.0059 - val_mae: 0.0193
# Epoch 81/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0131 - mse: 9.7077e-04 - mae: 0.0131 - val_loss: 0.0187 - val_mse: 0.0059 - val_mae: 0.0187
# Epoch 82/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0128 - mse: 9.2275e-04 - mae: 0.0128 - val_loss: 0.0187 - val_mse: 0.0058 - val_mae: 0.0187
# Epoch 83/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0127 - mse: 9.0183e-04 - mae: 0.0127 - val_loss: 0.0192 - val_mse: 0.0061 - val_mae: 0.0192
# Epoch 84/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0124 - mse: 8.7429e-04 - mae: 0.0124 - val_loss: 0.0192 - val_mse: 0.0061 - val_mae: 0.0192
# Epoch 85/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0122 - mse: 8.6372e-04 - mae: 0.0122 - val_loss: 0.0188 - val_mse: 0.0059 - val_mae: 0.0188
# Epoch 86/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0121 - mse: 8.3284e-04 - mae: 0.0121 - val_loss: 0.0190 - val_mse: 0.0061 - val_mae: 0.0190
# Epoch 87/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0118 - mse: 8.1606e-04 - mae: 0.0118 - val_loss: 0.0190 - val_mse: 0.0059 - val_mae: 0.0190
# Epoch 88/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0116 - mse: 7.9721e-04 - mae: 0.0116 - val_loss: 0.0190 - val_mse: 0.0060 - val_mae: 0.0190
# Epoch 89/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0115 - mse: 7.8736e-04 - mae: 0.0115 - val_loss: 0.0192 - val_mse: 0.0060 - val_mae: 0.0192
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 90/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0110 - mse: 7.2877e-04 - mae: 0.0110 - val_loss: 0.0191 - val_mse: 0.0060 - val_mae: 0.0191
# Epoch 91/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0108 - mse: 6.7290e-04 - mae: 0.0108 - val_loss: 0.0190 - val_mse: 0.0060 - val_mae: 0.0190
# Epoch 92/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0107 - mse: 6.5724e-04 - mae: 0.0107 - val_loss: 0.0191 - val_mse: 0.0060 - val_mae: 0.0191
# Epoch 93/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0106 - mse: 6.4358e-04 - mae: 0.0106 - val_loss: 0.0191 - val_mse: 0.0060 - val_mae: 0.0191
# Epoch 94/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0105 - mse: 6.3371e-04 - mae: 0.0105 - val_loss: 0.0192 - val_mse: 0.0060 - val_mae: 0.0192
# Epoch 95/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0104 - mse: 6.2313e-04 - mae: 0.0104 - val_loss: 0.0193 - val_mse: 0.0060 - val_mae: 0.0193
# Epoch 96/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0103 - mse: 6.1727e-04 - mae: 0.0103 - val_loss: 0.0194 - val_mse: 0.0060 - val_mae: 0.0194
# Epoch 97/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0103 - mse: 6.1488e-04 - mae: 0.0103 - val_loss: 0.0193 - val_mse: 0.0060 - val_mae: 0.0193
# Epoch 98/100
# 422/422 [==============================] - 95s 224ms/step - loss: 0.0102 - mse: 6.0169e-04 - mae: 0.0102 - val_loss: 0.0192 - val_mse: 0.0061 - val_mae: 0.0192
# Epoch 99/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0101 - mse: 5.9188e-04 - mae: 0.0101 - val_loss: 0.0195 - val_mse: 0.0061 - val_mae: 0.0195
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 100/100
# 422/422 [==============================] - 95s 225ms/step - loss: 0.0100 - mse: 5.7478e-04 - mae: 0.0100 - val_loss: 0.0193 - val_mse: 0.0060 - val_mae: 0.0193
#
# Loading network weights from 'weights_best.h5'.
# Training, done.
# Time elapsed: 2.0 hour(s) 39.0 min(s) 46 sec(s)
# Remember you can also plot:
# dict_keys(['val_loss', 'val_mse', 'val_mae', 'loss', 'mse', 'mae', 'lr'])
